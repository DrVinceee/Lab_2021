# %% [markdown]
# # Lab 5: BWA比对和MACS2峰调用
#
# 本lab主要涉及生物信息学工具的命令行使用，包括BWA比对和MACS2峰调用。
#
# 这些工具主要通过Bash脚本在服务器上运行。Python可以用于下游数据分析。

# %%
# Python可用于读取和分析peak calling结果
import pandas as pd
import matplotlib.pyplot as plt

# 示例：读取MACS2输出
# peaks = pd.read_csv('peaks.narrowPeak', sep='\t', header=None)
print('生物信息学数据分析准备就绪')
