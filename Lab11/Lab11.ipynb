# %% [markdown]
# # Lab 11: CRISPR筛选分析 (MAGeCK)
#
# MAGeCK主要通过命令行运行，Python可用于结果可视化和下游分析。
#
# **MAGeCK命令示例**:
# ```bash
# # 计数
# mageck count -l library.csv -n OUT \
#   --sample-label Day0,Day23 \
#   --fastq Day0.fastq.gz Day23.fastq.gz
#
# # 统计检验
# mageck test -k OUT.count.txt -t Day23 -c Day0 -n OUT
# ```

# %%
# MAGeCK结果分析
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 读取MAGeCK输出
# gene_summary = pd.read_csv('OUT.gene_summary.txt', sep='\t')

print('CRISPR筛选分析准备就绪')
