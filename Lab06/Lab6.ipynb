# %% [markdown]
# # Lab 6: ATAC-seq分析和LISA
#
# 本lab涵盖ATAC-seq数据分析和LISA转录因子预测。
#
# 主要工具为BEDTools（命令行）和LISA（Python/命令行）。

# %%
# ATAC-seq数据分析
import pandas as pd
import pybedtools  # BEDTools的Python接口

# 注意：pybedtools需要单独安装
# pip install pybedtools

print('ATAC-seq分析工具准备就绪')
