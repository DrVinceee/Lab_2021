# %% [markdown]
# # Lab 10: 生存分析
#
# 本notebook使用lifelines库进行生存分析，这是Python中survival包的替代品。
#
# **R vs Python对照**:
# - R::survival::Surv → lifelines.utils.Surv
# - R::survival::survfit → lifelines.KaplanMeierFitter
# - R::survival::coxph → lifelines.CoxPHFitter
# - R::glmnet (cox) → lifelines.CoxPHFitter + sklearn特征选择

# %%
# 安装lifelines: pip install lifelines
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from lifelines import KaplanMeierFitter, CoxPHFitter
from lifelines.statistics import logrank_test

print('生存分析工具准备就绪')
